# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_ndn = {}
for exp in range(1):
    results_ndn[f'exp{exp+1}'] = {}
    exp_res = results_ndn[f'exp{exp+1}']
    for consumers in [5]:
        exp_res[f'{consumers}consumers'] = {}
        con_res = exp_res[f'{consumers}consumers']
        for n in range(consumers):
            con_res[f'node{n}'] = {}
            node_res = con_res[f'node{n}']
            for latency in ['50', '100']:
                node_res[f'latency{latency}'] = {}
                print(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_1.csv')
                node_res[f'latency{latency}']['try1'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_1.csv')
                node_res[f'latency{latency}']['try2'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_2.csv')
                node_res[f'latency{latency}']['try3'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_3.csv')
# Out:
# ~/work/NDNProject/ndnlogs/exp1_node0_latency50_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node0_latency100_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node0_latency50_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node0_latency100_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node1_latency50_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node1_latency100_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node2_latency50_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node2_latency100_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node3_latency50_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node3_latency100_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node4_latency50_5consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node4_latency100_5consumers_1.csv

# %%
latency = 'latency100'
num_consumers = '5consumers'

# %%
node0 = results_ndn['exp1'][num_consumers]['node0'][latency]['try1']
node1 = results_ndn['exp1'][num_consumers]['node1'][latency]['try1']
node2 = results_ndn['exp1'][num_consumers]['node2'][latency]['try1']
node3 = results_ndn['exp1'][num_consumers]['node3'][latency]['try1']
node4 = results_ndn['exp1'][num_consumers]['node4'][latency]['try1']
print(node0.keys())
# node0.plot.line()
# node1.plot.line()
df = pd.DataFrame({'node0':node0[' segment latency'], 'node1':node1[' segment latency'], 'node2':node2[' segment latency'], 'node3':node3[' segment latency'], 'node4':node4[' segment latency']}, index=range(40))
df.plot.line(xlabel='segment number', ylabel='latency (s)') 
df = pd.DataFrame({'node0':node0[' segment latency'], 'node1':node1[' segment latency'], 'node2':node2[' segment latency'], 'node3':node3[' segment latency'], 'node4':node4[' segment latency']}, index=range(40,120))
df.plot.line(xlabel='segment number', ylabel='latency (s)') 
df = pd.DataFrame({'node0':node0[' segment latency'], 'node4':node4[' segment latency']}, index=range(40))
df.plot.line(xlabel='segment number', ylabel='latency (s)')
# Out:
# Index(['time since start', ' playback time', ' playback segments',
#        ' buffer size', ' remaining segments', ' segments', ' bitrate index',
#        ' segment latency', ' times buffered', ' time spent buffering',
#        ' bit rate'],
#       dtype='object')
# <AxesSubplot:xlabel='segment number', ylabel='latency (s)'>

# %%
df = pd.DataFrame({'node0':node0[' bit rate'], 'node1':node1[' bit rate'], 'node2':node2[' bit rate'], 'node3':node3[' bit rate'], 'node4':node4[' bit rate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node0':node0[' bit rate'], 'node1':node1[' bit rate'], 'node2':node2[' bit rate'], 'node3':node3[' bit rate'], 'node4':node4[' bit rate']}, index=range(40,120))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node0':node0[' bit rate'], 'node1':node1[' bit rate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node2':node2[' bit rate'], 'node3':node3[' bit rate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node4':node4[' bit rate'], 'node0':node0[' bit rate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node4':node4[' bit rate'], 'node3':node3[' bit rate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate')
# Out:
# <AxesSubplot:xlabel='segment number', ylabel='Bitrate'>

# %%
df = pd.DataFrame({'node0':node0[' buffer size'], 'node1':node1[' buffer size'], 'node2':node2[' buffer size'], 'node3':node3[' buffer size'], 'node4':node4[' buffer size']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Buffer Size') 
df = pd.DataFrame({'node0':node0[' buffer size'], 'node1':node1[' buffer size'], 'node2':node2[' buffer size'], 'node3':node3[' buffer size'], 'node4':node4[' buffer size']}, index=range(40,120))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Buffer Size')
# Out:
# <AxesSubplot:xlabel='segment number', ylabel='Buffer Size'>

# %%
results_dash = {}
for exp in range(1):
    results_dash[f'exp{exp+1}'] = {}
    exp_res = results_dash[f'exp{exp+1}']
    for consumers in [5]:
        exp_res[f'{consumers}consumers'] = {}
        con_res = exp_res[f'{consumers}consumers']
        for n in range(consumers):
            con_res[f'node{n}'] = {}
            node_res = con_res[f'node{n}']
            for latencyt in ['10', '50', '100']:
                    node_res[f'latency{latencyt}'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/dash_buffer_log_exp{exp+1}_node{n}_latency{latencyt}_{consumers}consumers_1.csv')

# %%
dash0 = results_dash['exp1'][num_consumers]['node0'][latency]
dash0 = dash0.query('Action == "StillPlaying"').reset_index()
dash1 = results_dash['exp1'][num_consumers]['node1'][latency]
dash1 = dash1.query('Action == "StillPlaying"').reset_index()
dash2 = results_dash['exp1'][num_consumers]['node2'][latency]
dash2 = dash2.query('Action == "StillPlaying"').reset_index()
dash3 = results_dash['exp1'][num_consumers]['node3'][latency]
dash3 = dash3.query('Action == "StillPlaying"').reset_index()
dash4 = results_dash['exp1'][num_consumers]['node4'][latency]
dash4 = dash4.query('Action == "StillPlaying"').reset_index()
print(dash4)
print(dash0.keys())
# node0.plot.line()
# node1.plot.line()
df = pd.DataFrame({'node0':dash0['Bitrate'], 'node1':dash1['Bitrate'], 'node2':dash2['Bitrate'], 'node3':dash3['Bitrate'], 'node4':dash4['Bitrate']}, index=range(40))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node0':dash0['Bitrate'], 'node1':dash1['Bitrate'], 'node2':dash2['Bitrate'], 'node3':dash3['Bitrate'], 'node4':dash4['Bitrate']}, index=range(40,80))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate') 
df = pd.DataFrame({'node0':dash0['Bitrate'], 'node1':dash1['Bitrate'], 'node2':dash2['Bitrate'], 'node3':dash3['Bitrate'], 'node4':dash4['Bitrate']}, index=range(80,120))
df.plot.line(color={'node0':'b','node1':'orange','node2':'g','node3':'r','node4':'purple'}, xlabel='segment number', ylabel='Bitrate')
# Out:
#      index   EpochTime  CurrentPlaybackTime  CurrentBufferSize  \
# 0        4    0.000875                    0                  0
# 1        9    4.001320                    4                  3
# 2       10    8.001131                    8                  2
# 3       15   12.001405                   12                  5
# 4       20   16.001241                   16                  8
# ..     ...         ...                  ...                ...
# 115    242  485.636225                  460                  4
# 116    243  489.636409                  464                  3
# 117    244  493.636222                  468                  2
# 118    245  497.636255                  472                  1
# 119    246  501.636215                  476                  0
#
#     CurrentPlaybackState        Action    Bitrate
# 0                   PLAY  StillPlaying    45226.0
# 1                   PLAY  StillPlaying    45226.0
# 2                   PLAY  StillPlaying    45226.0
# ...

# %%
node02 = results_ndn['exp1'][num_consumers]['node0'][latency]['try2']
node12 = results_ndn['exp1'][num_consumers]['node1'][latency]['try2']
node22 = results_ndn['exp1'][num_consumers]['node2'][latency]['try2']
node32 = results_ndn['exp1'][num_consumers]['node3'][latency]['try2']
node42 = results_ndn['exp1'][num_consumers]['node4'][latency]['try2']

node03 = results_ndn['exp1'][num_consumers]['node0'][latency]['try3']
node13 = results_ndn['exp1'][num_consumers]['node1'][latency]['try3']
node23 = results_ndn['exp1'][num_consumers]['node2'][latency]['try3']
node33 = results_ndn['exp1'][num_consumers]['node3'][latency]['try3']
node43 = results_ndn['exp1'][num_consumers]['node4'][latency]['try3']

dash_sum =  dash2['Bitrate'] + dash4['Bitrate'] + dash3['Bitrate']  + dash1['Bitrate'] + dash0['Bitrate'] 
dash_avg = dash_sum/5

ndn_sum = node0[' bit rate'] + node1[' bit rate'] + node2[' bit rate'] + node3[' bit rate'] + node4[' bit rate']
ndn_avg = ndn_sum/5 
ndn_sum2 = node02[' bit rate'] + node12[' bit rate'] + node22[' bit rate'] + node32[' bit rate'] + node42[' bit rate']
ndn_avg2 = ndn_sum2/5 
ndn_sum3 = node03[' bit rate'] + node13[' bit rate'] + node23[' bit rate'] + node33[' bit rate'] + node43[' bit rate']
ndn_avg3 = ndn_sum3/5 

fig, ax = plt.subplots()

ndn_avg.plot.line(xlabel='segment number', ylabel='bitrate', color='blue', xlim=(0,75))
ndn_avg2.plot.line(linestyle='-', color='purple')
ndn_avg3.plot.line(alpha=0.7,linestyle='--', color='aqua')
dash_avg.plot.line(color='red')

ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3', 'dash'])
fig, ax = plt.subplots()

dash_sum =  dash2['Bitrate'] + dash4['Bitrate'] + dash3['Bitrate']  + dash1['Bitrate'] + dash0['Bitrate'] 
dash_avg = dash_sum/5

ndn_avg.plot.line(xlabel='segment number', ylabel='bitrate', color='blue', xlim=(0,75))
ndn_avg2.plot.line(linestyle='-', color='purple')
ndn_avg3.plot.line(alpha=0.7,linestyle='--', color='aqua')
dash_avg.plot.line(color='red', xlim=(75,120))
ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3', 'dash'])

# %%
fig, ax = plt.subplots()

node0[' bit rate'].plot.line(xlabel='segment number', ylabel='bitrate', color='blue')
node02[' bit rate'].plot.line(color='aqua')
node03[' bit rate'].plot.line(color='purple')
dash0['Bitrate'].plot.line(color='red', xlim=(0,40))


ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3', 'dash'])

fig, ax = plt.subplots()
node0[' bit rate'].plot.line(xlabel='segment number', ylabel='bitrate', color='blue')
node02[' bit rate'].plot.line(color='aqua')
node03[' bit rate'].plot.line(color='purple')
dash0['Bitrate'].plot.line(color='red', xlim=(40,80))
ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3', 'dash'])

fig, ax = plt.subplots()
node0[' bit rate'].plot.line(xlabel='segment number', ylabel='bitrate', color='blue')
node02[' bit rate'].plot.line(color='aqua')
node03[' bit rate'].plot.line(color='purple')
dash0['Bitrate'].plot.line(color='red', xlim=(80,120))
ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3', 'dash'])

# %%
results_ndn = {}
for exp in range(1):
    results_ndn[f'exp{exp+1}'] = {}
    exp_res = results_ndn[f'exp{exp+1}']
    for consumers in [1]:
        exp_res[f'{consumers}consumers'] = {}
        con_res = exp_res[f'{consumers}consumers']
        for n in range(consumers):
            con_res[f'node{n}'] = {}
            node_res = con_res[f'node{n}']
            for latency in ['10', '50', '100']:
                node_res[f'latency{latency}'] = {}
                print(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_1.csv')
                node_res[f'latency{latency}']['try1'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_1.csv')
                node_res[f'latency{latency}']['try2'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_2.csv')
                node_res[f'latency{latency}']['try3'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_3.csv')
                node_res[f'latency{latency}']['try4'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_4.csv')
                node_res[f'latency{latency}']['try5'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/exp{exp+1}_node{n}_latency{latency}_{consumers}consumers_5.csv')
results_dash = {}
for exp in range(1):
    results_dash[f'exp{exp+1}'] = {}
    exp_res = results_dash[f'exp{exp+1}']
    for consumers in [1]:
        exp_res[f'{consumers}consumers'] = {}
        con_res = exp_res[f'{consumers}consumers']
        for n in range(consumers):
            con_res[f'node{n}'] = {}
            node_res = con_res[f'node{n}']
            for latencyt in ['10', '50', '100']:
                print(f'~/work/NDNProject/ndnlogs/dash_buffer_log_exp{exp+1}_node{n}_latency{latencyt}_{consumers}consumers_1.csv')
                node_res[f'latency{latencyt}'] = pd.read_csv(f'~/work/NDNProject/ndnlogs/dash_buffer_log_exp{exp+1}_node{n}_latency{latencyt}_{consumers}consumers_1.csv')
# Out:
# ~/work/NDNProject/ndnlogs/exp1_node0_latency10_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node0_latency50_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/exp1_node0_latency100_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/dash_buffer_log_exp1_node0_latency10_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/dash_buffer_log_exp1_node0_latency50_1consumers_1.csv
# ~/work/NDNProject/ndnlogs/dash_buffer_log_exp1_node0_latency100_1consumers_1.csv

# %%
latency = 'latency10'
num_consumers = '1consumers'

# %%
try1 = results_ndn['exp1'][num_consumers]['node0'][latency]['try1']
try2 = results_ndn['exp1'][num_consumers]['node0'][latency]['try2']
try3 = results_ndn['exp1'][num_consumers]['node0'][latency]['try3']
try4 = results_ndn['exp1'][num_consumers]['node0'][latency]['try4']
try5 = results_ndn['exp1'][num_consumers]['node0'][latency]['try5']

dash0 = results_dash['exp1'][num_consumers]['node0'][latency]
dash0 = dash0.query('Action == "StillPlaying"').reset_index()

# %%
fig, ax = plt.subplots()

try1[' bit rate'].plot.line(xlabel='segment number', ylabel='bitrate', color='blue')
try2[' bit rate'].plot.line(color='aqua', linestyle='--')
try3[' bit rate'].plot.line(color='purple', linestyle='--')
try4[' bit rate'].plot.line(color='green', linestyle='--')
try5[' bit rate'].plot.line(color='yellow', linestyle='-.')

dash0['Bitrate'].plot.line(color='red', xlim=(100,120))

ax.legend(['ndn run 1', 'ndn run 2', 'ndn run 3','ndn run 4', 'ndn run 5', 'dash'])
